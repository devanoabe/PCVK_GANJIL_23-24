# %% [markdown]
# <a href="https://colab.research.google.com/github/devanoabe/PCVK_GANJIL_23-24/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##LANGKAH 1
#
# Pada code awal, beberapa library yang akan digunakan adalah : **numphy, pandas, cv2, skimage, PIL, matploib**

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow #for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %% [markdown]
# ##LANGKAH 2
#
# untuk membaca dan menampilkan image

# %%
#Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://placekitten.com/800/571"]
#Baca dan tampilkan image
#Loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)                            #Read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)   #Resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)    #Convert color to RGB
  final_frame = cv.hconcat((image, image_2))        #Concatenate image
  cv2_imshow(final_frame)                           #Show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# ##LANGKAH 3
# pada praktikum ini adalah melihat ukuran file image, dengan cara sebagai
# berikut

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ", tinggi, " x ", lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286>

# %% [markdown]
# ##LANGKAH 4
# berikut digunakan untuk mengakses pixel dengan memberikan garis
# horizontal berwarna putih di tengah image

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# #TUGAS

# %% [markdown]
# Buat garis vertikal

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_4 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for x in range (tinggi):
  image_4[x, int(lebar/2)] = [255,255,255]
final_frame = cv.hconcat((image_2, image_4))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# garis menyilang diagonal pada image keluaran

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_5 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat menyilang diagonal pada image keluaran
for x in range (tinggi):
  image_4[x, int(lebar/2)] = [255,255,255]
final_frame = cv.hconcat((image_2, image_4))
cv2_imshow(final_frame)

# %% [markdown]
# ##Tugas Kelompok 12

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2
import matplotlib.pyplot as plt

# Path file gambar
image_path = '/content/drive/MyDrive/PCVK MINGGU 2/KTP.jpeg'

# Baca gambar menggunakan OpenCV
image = cv2.imread(image_path)

# Ubah warna gambar dari BGR ke RGB
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Tampilkan gambar menggunakan Matplotlib
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
# Mengubah warna pada bagian tempat tanggal lahir
for y in range(190, 450):  # lebar
    for x in range(140, 160):  # panjang
        image[x, y] = 253, 215, 3 # warna

# Mengubah warna pada bagian jenis kelamin
for y in range(190, 300):  # lebar
    for x in range(165, 185):  # panjang
        image[x, y] = [255, 0, 0] # warna

# Tampilkan gambar dengan kotak warna yang telah dimodifikasi
plt.imshow(image)
plt.axis('off')
plt.show()
